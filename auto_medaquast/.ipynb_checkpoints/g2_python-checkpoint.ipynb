# %% [markdown]
# # import library

# %%
##system
import sys, os, argparse
import pandas as pd

## statistics
import tableone
from tableone import TableOne
import pingouin as pg

## plot
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt
# Out:
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/xarray/core/pycompat.py:37: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   duck_array_version = LooseVersion("0.0.0")
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/xarray/core/pycompat.py:37: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   duck_array_version = LooseVersion("0.0.0")
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/xarray/core/pycompat.py:37: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   duck_array_version = LooseVersion("0.0.0")
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/xarray/core/npcompat.py:82: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(np.__version__) >= "1.20.0":
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/xarray/core/pdcompat.py:45: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(pd.__version__) < "0.25.0":
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/seaborn/rcmod.py:82: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) >= "3.0":
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)

# %%
parser = argparse.ArgumentParser(description='manual to this script',argument_default="")

# %%
parser.add_argument()
# Out:
# <bound method _ActionsContainer.add_argument of ArgumentParser(prog='ipykernel_launcher.py', usage=None, description='manual to this script', formatter_class=<class 'argparse.HelpFormatter'>, conflict_handler='error', add_help=True)>

# %% [markdown]
# # user argument

# %%
argparse
# Out:
# <module 'argparse' from '/home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/argparse.py'>

# %%
out_quast="out_quast"

# %%
depth_file="strain_depth.csv"

# %%
goal_std="STANDARD_GENOME.fa.gz"
goal_std=goal_std.split(".")[0]
goal_std
# Out:
# 'STANDARD_GENOME'

# %%
out_python="out_quast_after_py"

# %%
meta="groupby_info.csv"

# %% [markdown]
# # get the depth information

# %%
df_depth=pd.read_csv(depth_file,header=None)
df_depth.columns=["strain","depth"]
df_depth=df_depth.sort_values("depth",ascending=False)
df_depth["depth_str"]=df_depth.depth.map(lambda x:"{:.2f}".format(x))
df_depth["name"]=df_depth["strain"]+" ("+df_depth["depth_str"]+")"
df_depth=df_depth.reindex(columns=["strain","name"])
df_depth.columns=["Assemblies","name"]
df_depth
# Out:
#                       Assemblies                                 name
# 10         Klebsiella_pneumoniae        Klebsiella_pneumoniae (65.33)
# 15            Pseudomonas_putida           Pseudomonas_putida (64.15)
# 0        Acinetobacter_baumannii      Acinetobacter_baumannii (53.80)
# 16    Staphylococcus_epidermidis   Staphylococcus_epidermidis (43.07)
# 4           Enterobacter_cloacae         Enterobacter_cloacae (39.12)
# 3        Capnocytophaga_ochracea      Capnocytophaga_ochracea (21.42)
# 12            Neisseria_subflava           Neisseria_subflava (18.80)
# 9           Jonquetella_anthropi         Jonquetella_anthropi (16.21)
# 11         Lactobacillus_reuteri        Lactobacillus_reuteri (13.67)
# 2         Bifidobacterium_longum        Bifidobacterium_longum (9.59)
# 6               Finegoldia_magna              Finegoldia_magna (5.05)
# 17   Streptococcus_parasanguinis   Streptococcus_parasanguinis (4.79)
# 1   Bifidobacterium_adolescentis  Bifidobacterium_adolescentis (4.28)
# 5            Eubacterium_siraeum           Eubacterium_siraeum (3.81)
# 7        Fusobacterium_nucleatum       Fusobacterium_nucleatum (3.40)
# 8           Helicobacter_cinaedi          Helicobacter_cinaedi (3.03)
# 13     Parascardovia_denticolens     Parascardovia_denticolens (2.58)
# 14               Prevotella_oris               Prevotella_oris (1.69)

# %% [markdown]
# # get metadata

# %%
df_meta=pd.read_csv(meta,header=None)
df_meta.columns=["file_name","group"]
df_meta["file_name"]=df_meta["file_name"].map(lambda x:x.split(".")[0])
df_meta["group"]=df_meta["group"].astype(str)
df_meta
# Out:
#                 file_name       group
# 0    canu_after_pilon_all   pilon_all
# 1   canu_after_pilon_base  pilon_base
# 2       canu_before_pilon         raw
# 3   flye_after_pilon_base  pilon_base
# 4       flye_before_pilon         raw
# 5    miniasm_before_pilon         raw
# 6      miniasm_pilon_base  pilon_base
# 7      raven_before_pilon         raw
# 8        raven_pilon_base  pilon_base
# 9         STANDARD_GENOME         nan
# 10    wtdbg2_before_pilon         raw
# 11      wtdbg2_pilon_base  pilon_base

# %%
#在这里，这个大写的GOLD_STD在排序的时候会始终保持在最前面
df_meta.at[df_meta["file_name"]==goal_std,"group"]="GOLD_STD"
df_meta
# Out:
#                 file_name       group
# 0    canu_after_pilon_all   pilon_all
# 1   canu_after_pilon_base  pilon_base
# 2       canu_before_pilon         raw
# 3   flye_after_pilon_base  pilon_base
# 4       flye_before_pilon         raw
# 5    miniasm_before_pilon         raw
# 6      miniasm_pilon_base  pilon_base
# 7      raven_before_pilon         raw
# 8        raven_pilon_base  pilon_base
# 9         STANDARD_GENOME    GOLD_STD
# 10    wtdbg2_before_pilon         raw
# 11      wtdbg2_pilon_base  pilon_base

# %%
len(df_meta.loc[df_meta["file_name"]==goal_std,"group"])
# Out:
# 1

# %%
df_meta
# Out:
#                 file_name       group
# 0    canu_after_pilon_all   pilon_all
# 1   canu_after_pilon_base  pilon_base
# 2       canu_before_pilon         raw
# 3   flye_after_pilon_base  pilon_base
# 4       flye_before_pilon         raw
# 5    miniasm_before_pilon         raw
# 6      miniasm_pilon_base  pilon_base
# 7      raven_before_pilon         raw
# 8        raven_pilon_base  pilon_base
# 9         STANDARD_GENOME         aaa
# 10    wtdbg2_before_pilon         raw
# 11      wtdbg2_pilon_base  pilon_base

# %%
groupby="group"

# %% [markdown]
# # get deta

# %%
tsv_dir="{}/summary/TSV/".format(out_quast)
m_list = [e.split(".tsv")[0] for e in os.listdir(tsv_dir)]
for o, e in enumerate(m_list):
    ##read csv
    metric = e
    df = pd.read_csv(os.path.join(tsv_dir,metric)+".tsv", sep="\t")
    
    ##align name, if df_depth existed, then align, if not existed, just use the Assemblies as name
    try:
        df = df_depth.merge(df, how="outer")
        df.drop(columns=["Assemblies"], inplace=True)
        ##make index col to index
        df.set_index("name", inplace=True)
    except:
        df.rename(columns={"Assemblies":"name"},inplace=True)
        df.set_index("name", inplace=True)
    
    ##force to float
    df = df.apply(pd.to_numeric, errors="coerce")
    
    ## the nga50 is special
    if e == "NGA50":
        df_nga50 = df
    if e == "Genome_fraction":
        df_gf = df
    ##get melt_matrix
    
    df_melt = df.reset_index()
    df_melt = df_melt.melt(id_vars=["name"], var_name="file_name", value_name=metric)
    df_melt

    ##get merge
    if o == 0:
        df_final = df_melt
    else:
        id_col = ["name", "file_name"]
        df_final = df_final.merge(df_melt, left_on=id_col, right_on=id_col)
df_final
# Out:
#                                    name          file_name  \
# 0         Klebsiella_pneumoniae (65.33)    STANDARD_GENOME
# 1            Pseudomonas_putida (64.15)    STANDARD_GENOME
# 2       Acinetobacter_baumannii (53.80)    STANDARD_GENOME
# 3    Staphylococcus_epidermidis (43.07)    STANDARD_GENOME
# 4          Enterobacter_cloacae (39.12)    STANDARD_GENOME
# ..                                  ...                ...
# 211          Eubacterium_siraeum (3.81)  wtdbg2_pilon_base
# 212      Fusobacterium_nucleatum (3.40)  wtdbg2_pilon_base
# 213         Helicobacter_cinaedi (3.03)  wtdbg2_pilon_base
# 214    Parascardovia_denticolens (2.58)  wtdbg2_pilon_base
# 215              Prevotella_oris (1.69)  wtdbg2_pilon_base
#
#      Total_aligned_length  num_Ns_per_100_kbp     NGA50  \
# 0               5046860.0                 0.0   98425.0
# 1               3323660.0                 0.0    6086.0
# 2                     NaN                 NaN       NaN
# 3               2361574.0                 0.0  410790.0
# 4               4608498.0                 0.0   54793.0
# ..                    ...                 ...       ...
# 211               25093.0                 0.0       NaN
# 212                1588.0                 0.0       NaN
# 213               11342.0                 0.0       NaN
# 214                  90.0                 0.0       NaN
# 215                1227.0                 0.0       NaN
#
#      Misassembled_contigs_length  Genome_fraction  Largest_contig  \
# 0                      5333942.0           84.298       6156701.0
# 1                      6156701.0           53.554       6156701.0
# 2                            NaN              NaN             NaN
# 3                      2466502.0           93.014       6156701.0
# 4                      4954728.0           82.572       6156701.0
# ..                           ...              ...             ...
# 211                          0.0            0.889       1979177.0
# 212                          0.0            0.029       1923465.0
# 213                      11342.0            0.515       1923465.0
# 214                          0.0            0.005        282440.0
# 215                          0.0            0.018       1923465.0
#
#      num_contigs  Total_length_(ge_10000_bp)  Total_length_(ge_50000_bp)  \
# 0            8.0                  21507655.0                  21507655.0
# 1            6.0                  12912234.0                  12912234.0
# 2            NaN                         NaN                         NaN
# 3            4.0                  11028484.0                  11008367.0
# 4            8.0                  21507655.0                  21507655.0
# ..           ...                         ...                         ...
# 211          7.0                   2425457.0                   2425457.0
# 212          3.0                   3142325.0                   3142325.0
# 213          3.0                   2217247.0                   2205905.0
# 214          1.0                    282440.0                    282440.0
# 215          3.0                   3142325.0                   3142325.0
#
#      num_indels_per_100_kbp  Total_length  Total_length_(ge_1000_bp)  LGA50  \
# 0                     32.06    21507655.0                 21507655.0   19.0
# 1                    273.43    12912234.0                 12912234.0  125.0
# 2                       NaN           NaN                        NaN    NaN
# 3                     21.05    11028484.0                 11028484.0    3.0
# 4                     32.55    21507655.0                 21507655.0   25.0
# ..                      ...           ...                        ...    ...
# 211                 1283.23     2454746.0                  2454746.0    NaN
# 212                  566.75     3142325.0                  3142325.0    NaN
# 213                 2856.64     2217247.0                  2217247.0    NaN
# 214                    0.00      282440.0                   282440.0    NaN
# 215                  326.00     3142325.0                  3142325.0    NaN
#
#      num_misassemblies  Duplication_ratio  num_mismatches_per_100_kbp  \
# 0                 97.0              1.031                      812.58
# 1                225.0              1.007                     7579.99
# 2                  NaN                NaN                         NaN
# 3                 37.0              1.007                      396.18
# 4                130.0              1.037                     1123.47
# ..                 ...                ...                         ...
# 211                0.0              0.985                     2968.96
# 212                0.0              2.233                     6045.34
# 213                1.0              0.994                     1613.47
# 214                0.0              1.000                     4444.44
# 215                0.0              2.119                     5460.47
#
#      Largest_alignment
# 0             275893.0
# 1             104180.0
# 2                  NaN
# 3             631022.0
# 4             280437.0
# ..                 ...
# 211             6079.0
# 212              290.0
# 213             5981.0
# 214               90.0
# 215              199.0
#
# [216 rows x 19 columns]

# %% [markdown]
# # merge with meta data

# %%
df_stat = df_final.merge(df_meta)
df_stat
# Out:
#                                    name          file_name  \
# 0         Klebsiella_pneumoniae (65.33)    STANDARD_GENOME
# 1            Pseudomonas_putida (64.15)    STANDARD_GENOME
# 2       Acinetobacter_baumannii (53.80)    STANDARD_GENOME
# 3    Staphylococcus_epidermidis (43.07)    STANDARD_GENOME
# 4          Enterobacter_cloacae (39.12)    STANDARD_GENOME
# ..                                  ...                ...
# 211          Eubacterium_siraeum (3.81)  wtdbg2_pilon_base
# 212      Fusobacterium_nucleatum (3.40)  wtdbg2_pilon_base
# 213         Helicobacter_cinaedi (3.03)  wtdbg2_pilon_base
# 214    Parascardovia_denticolens (2.58)  wtdbg2_pilon_base
# 215              Prevotella_oris (1.69)  wtdbg2_pilon_base
#
#      Total_aligned_length  num_Ns_per_100_kbp     NGA50  \
# 0               5046860.0                 0.0   98425.0
# 1               3323660.0                 0.0    6086.0
# 2                     NaN                 NaN       NaN
# 3               2361574.0                 0.0  410790.0
# 4               4608498.0                 0.0   54793.0
# ..                    ...                 ...       ...
# 211               25093.0                 0.0       NaN
# 212                1588.0                 0.0       NaN
# 213               11342.0                 0.0       NaN
# 214                  90.0                 0.0       NaN
# 215                1227.0                 0.0       NaN
#
#      Misassembled_contigs_length  Genome_fraction  Largest_contig  \
# 0                      5333942.0           84.298       6156701.0
# 1                      6156701.0           53.554       6156701.0
# 2                            NaN              NaN             NaN
# 3                      2466502.0           93.014       6156701.0
# 4                      4954728.0           82.572       6156701.0
# ..                           ...              ...             ...
# 211                          0.0            0.889       1979177.0
# 212                          0.0            0.029       1923465.0
# 213                      11342.0            0.515       1923465.0
# 214                          0.0            0.005        282440.0
# 215                          0.0            0.018       1923465.0
#
#      num_contigs  Total_length_(ge_10000_bp)  Total_length_(ge_50000_bp)  \
# 0            8.0                  21507655.0                  21507655.0
# 1            6.0                  12912234.0                  12912234.0
# 2            NaN                         NaN                         NaN
# 3            4.0                  11028484.0                  11008367.0
# 4            8.0                  21507655.0                  21507655.0
# ..           ...                         ...                         ...
# 211          7.0                   2425457.0                   2425457.0
# 212          3.0                   3142325.0                   3142325.0
# 213          3.0                   2217247.0                   2205905.0
# 214          1.0                    282440.0                    282440.0
# 215          3.0                   3142325.0                   3142325.0
#
#      num_indels_per_100_kbp  Total_length  Total_length_(ge_1000_bp)  LGA50  \
# 0                     32.06    21507655.0                 21507655.0   19.0
# 1                    273.43    12912234.0                 12912234.0  125.0
# 2                       NaN           NaN                        NaN    NaN
# 3                     21.05    11028484.0                 11028484.0    3.0
# 4                     32.55    21507655.0                 21507655.0   25.0
# ..                      ...           ...                        ...    ...
# 211                 1283.23     2454746.0                  2454746.0    NaN
# 212                  566.75     3142325.0                  3142325.0    NaN
# 213                 2856.64     2217247.0                  2217247.0    NaN
# 214                    0.00      282440.0                   282440.0    NaN
# 215                  326.00     3142325.0                  3142325.0    NaN
#
#      num_misassemblies  Duplication_ratio  num_mismatches_per_100_kbp  \
# 0                 97.0              1.031                      812.58
# 1                225.0              1.007                     7579.99
# 2                  NaN                NaN                         NaN
# 3                 37.0              1.007                      396.18
# 4                130.0              1.037                     1123.47
# ..                 ...                ...                         ...
# 211                0.0              0.985                     2968.96
# 212                0.0              2.233                     6045.34
# 213                1.0              0.994                     1613.47
# 214                0.0              1.000                     4444.44
# 215                0.0              2.119                     5460.47
#
#      Largest_alignment       group
# 0             275893.0    GOLD_STD
# 1             104180.0    GOLD_STD
# 2                  NaN    GOLD_STD
# 3             631022.0    GOLD_STD
# 4             280437.0    GOLD_STD
# ..                 ...         ...
# 211             6079.0  pilon_base
# 212              290.0  pilon_base
# 213             5981.0  pilon_base
# 214               90.0  pilon_base
# 215              199.0  pilon_base
#
# [216 rows x 20 columns]

# %% [markdown]
# ## some metrics should divide by 1000

# %%
divide_1000=["Total_length_(ge_1000_bp)","Total_length_(ge_10000_bp)","Total_length_(ge_50000_bp)",
             "Largest_contig","Total_length","Largest_alignment","Total_aligned_length","NGA50","Misassembled_contigs_length"]

# %%
for col in divide_1000:
    #name
    o_name=col
    n_name="{}_(Kbp)".format(o_name)
    #calculation
    df_stat[n_name]=df_stat[o_name]/1000
    
df_stat=df_stat.drop(columns=divide_1000)

# %%
df_stat.columns
# Out:
# Index(['name', 'file_name', 'num_Ns_per_100_kbp', 'Genome_fraction',
#        'num_contigs', 'num_indels_per_100_kbp', 'LGA50', 'num_misassemblies',
#        'Duplication_ratio', 'num_mismatches_per_100_kbp', 'group',
#        'Total_length_(ge_1000_bp)_(Kbp)', 'Total_length_(ge_10000_bp)_(Kbp)',
#        'Total_length_(ge_50000_bp)_(Kbp)', 'Largest_contig_(Kbp)',
#        'Total_length_(Kbp)', 'Largest_alignment_(Kbp)',
#        'Total_aligned_length_(Kbp)', 'NGA50_(Kbp)',
#        'Misassembled_contigs_length_(Kbp)'],
#       dtype='object')

# %% [markdown]
# # tableone

# %%
stat_col4_tableone=["num_contigs","Total_length_(ge_1000_bp)_(Kbp)","Total_length_(ge_10000_bp)_(Kbp)","Total_length_(ge_50000_bp)_(Kbp)",
                   "Largest_contig_(Kbp)","Total_length_(Kbp)","Genome_fraction","NGA50_(Kbp)","Largest_alignment_(Kbp)","Total_aligned_length_(Kbp)",
                   "num_misassemblies","Misassembled_contigs_length_(Kbp)","num_mismatches_per_100_kbp","num_indels_per_100_kbp","Duplication_ratio"]
stat_col4_fiure=stat_col4_tableone
stat_col4_fiure.append("num_Ns_per_100_kbp")

# %%
mytable = TableOne(
    df_stat,
    columns=stat_col4_tableone,
    groupby=[groupby],
    overall=False,
    pval=True,
    decimals=2,
)
mytable.tabulate(tablefmt="html")
# Out:
# '<table>\n<thead>\n<tr><th>                                            </th><th>  </th><th>Missing  </th><th>GOLD_STD         </th><th>pilon_all        </th><th>pilon_base       </th><th>raw              </th><th>P-Value  </th></tr>\n</thead>\n<tbody>\n<tr><td>n                                           </td><td>  </td><td>         </td><td>18               </td><td>18               </td><td>90               </td><td>90               </td><td>         </td></tr>\n<tr><td>num_contigs, mean (SD)                      </td><td>  </td><td>14       </td><td>9.94 (13.73)     </td><td>28.76 (38.22)    </td><td>22.25 (25.73)    </td><td>21.75 (25.34)    </td><td>0.196    </td></tr>\n<tr><td>Total_length_(ge_1000_bp)_(Kbp), mean (SD)  </td><td>  </td><td>14       </td><td>9864.98 (5932.11)</td><td>7408.42 (5160.21)</td><td>5897.41 (4449.43)</td><td>5986.50 (4201.59)</td><td>0.007    </td></tr>\n<tr><td>Total_length_(ge_10000_bp)_(Kbp), mean (SD) </td><td>  </td><td>14       </td><td>9860.51 (5933.07)</td><td>7355.07 (5163.04)</td><td>5870.83 (4454.14)</td><td>5961.65 (4205.65)</td><td>0.007    </td></tr>\n<tr><td>Total_length_(ge_50000_bp)_(Kbp), mean (SD) </td><td>  </td><td>14       </td><td>9803.87 (5940.10)</td><td>7085.87 (5214.17)</td><td>5661.35 (4475.87)</td><td>5753.36 (4233.25)</td><td>0.005    </td></tr>\n<tr><td>Largest_contig_(Kbp), mean (SD)             </td><td>  </td><td>14       </td><td>4510.83 (2105.32)</td><td>2419.55 (1513.76)</td><td>2346.47 (1146.55)</td><td>2459.24 (1084.80)</td><td>&lt;0.001   </td></tr>\n<tr><td>Total_length_(Kbp), mean (SD)               </td><td>  </td><td>14       </td><td>9865.32 (5931.84)</td><td>7408.42 (5160.21)</td><td>5897.41 (4449.43)</td><td>5986.50 (4201.59)</td><td>0.007    </td></tr>\n<tr><td>Genome_fraction, mean (SD)                  </td><td>  </td><td>15       </td><td>82.43 (14.21)    </td><td>35.89 (42.01)    </td><td>35.43 (40.21)    </td><td>35.42 (40.36)    </td><td>&lt;0.001   </td></tr>\n<tr><td>NGA50_(Kbp), mean (SD)                      </td><td>  </td><td>133      </td><td>481.57 (958.39)  </td><td>73.09 (48.52)    </td><td>103.96 (118.51)  </td><td>102.40 (118.26)  </td><td>0.023    </td></tr>\n<tr><td>Largest_alignment_(Kbp), mean (SD)          </td><td>  </td><td>15       </td><td>578.77 (920.19)  </td><td>100.32 (191.22)  </td><td>117.93 (208.37)  </td><td>118.91 (209.54)  </td><td>&lt;0.001   </td></tr>\n<tr><td>Total_aligned_length_(Kbp), mean (SD)       </td><td>  </td><td>15       </td><td>2379.87 (1066.25)</td><td>1231.50 (1769.45)</td><td>1211.10 (1693.29)</td><td>1213.07 (1698.84)</td><td>0.056    </td></tr>\n<tr><td>num_misassemblies, mean (SD)                </td><td>  </td><td>15       </td><td>90.65 (70.38)    </td><td>30.71 (47.11)    </td><td>32.45 (49.78)    </td><td>32.00 (48.77)    </td><td>&lt;0.001   </td></tr>\n<tr><td>Misassembled_contigs_length_(Kbp), mean (SD)</td><td>  </td><td>15       </td><td>2381.79 (1744.50)</td><td>1025.79 (1917.09)</td><td>1084.14 (1832.79)</td><td>1092.54 (1840.15)</td><td>0.053    </td></tr>\n<tr><td>num_mismatches_per_100_kbp, mean (SD)       </td><td>  </td><td>15       </td><td>2331.99 (2388.09)</td><td>3424.84 (2555.83)</td><td>3355.26 (2446.20)</td><td>3437.02 (2464.32)</td><td>0.397    </td></tr>\n<tr><td>num_indels_per_100_kbp, mean (SD)           </td><td>  </td><td>15       </td><td>93.07 (90.43)    </td><td>256.40 (403.77)  </td><td>414.01 (556.37)  </td><td>1287.77 (987.10) </td><td>&lt;0.001   </td></tr>\n<tr><td>Duplication_ratio, mean (SD)                </td><td>  </td><td>15       </td><td>1.01 (0.01)      </td><td>1.64 (1.21)      </td><td>1.38 (0.91)      </td><td>1.38 (0.86)      </td><td>0.224    </td></tr>\n<tr><td>num_Ns_per_100_kbp, mean (SD)               </td><td>  </td><td>14       </td><td>110.14 (305.96)  </td><td>0.00 (0.00)      </td><td>0.00 (0.00)      </td><td>0.00 (0.00)      </td><td>&lt;0.001   </td></tr>\n</tbody>\n</table>'

# %%
os.makedirs(out_python,exist_ok=True)
out_file="{}/out_test.csv".format(out_python)
mytable.to_csv(out_file)

# %% [markdown]
# # pair-wise

# %%
out_pair_wise=os.path.join(out_python,"pair_wise")
os.makedirs(out_pair_wise,exist_ok=True)
for col in stat_col4_tableone:
    df_pair=pg.pairwise_ttests(data=df_stat,between="group",dv="Misassembled_contigs_length_(Kbp)",padjust="fdr_bh")
    df_pair=df_pair.sort_values("p-unc")
    df_pair.to_csv("{}/{}.csv".format(out_pair_wise,col))

# %% [markdown]
# # figures

# %%
x="file_name"

# %%
##这里，由于 G
order=df_stat[[x,groupby]].sort_values(groupby)[x].value_counts(sort=False).index.to_list()
order
# Out:
# ['STANDARD_GENOME',
#  'canu_after_pilon_all',
#  'miniasm_pilon_base',
#  'raven_pilon_base',
#  'wtdbg2_pilon_base',
#  'flye_after_pilon_base',
#  'canu_after_pilon_base',
#  'flye_before_pilon',
#  'canu_before_pilon',
#  'wtdbg2_before_pilon',
#  'raven_before_pilon',
#  'miniasm_before_pilon']

# %%
for o,c in enumerate(stat_col4_fiure):
    fig, ax = plt.subplots(1, 1, figsize=(6, 4))
    sns.boxplot(x="file_name",y=c, data=df_stat, hue=groupby, order=order, ax=ax, width=0.5, dodge=False)
    ax.set_xticklabels(ax.get_xticklabels(),fontdict={"size": "15","rotation":"90"})
    ax.set_yticklabels(ax.get_yticks(),fontdict={"size": "15"})
    #ax.set_xlabel("Pipeline", fontdict={"size": "25"})
    ax.set_ylabel(ax.get_ylabel(), fontdict={"size": "25"})
    if c=="num_contigs":
        ax.legend(bbox_to_anchor=(1, 1))
    else:
        ax.legend([],frameon=False)
    fig.savefig(
        "{}/{}.png".format(out_python,c),
        dpi=600,
        bbox_inches="tight",
        transparent=False,
    )
    plt.close()
# Out:
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/seaborn/categorical.py:381: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) < "3.0":
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /tmp/ipykernel_1284770/310630204.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticks(),fontdict={"size": "15"})
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/seaborn/categorical.py:381: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) < "3.0":
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /tmp/ipykernel_1284770/310630204.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticks(),fontdict={"size": "15"})
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/seaborn/categorical.py:381: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) < "3.0":
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /tmp/ipykernel_1284770/310630204.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticks(),fontdict={"size": "15"})
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/seaborn/categorical.py:381: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) < "3.0":
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /tmp/ipykernel_1284770/310630204.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticks(),fontdict={"size": "15"})
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/seaborn/categorical.py:381: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) < "3.0":
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /tmp/ipykernel_1284770/310630204.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticks(),fontdict={"size": "15"})
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/seaborn/categorical.py:381: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) < "3.0":
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /tmp/ipykernel_1284770/310630204.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticks(),fontdict={"size": "15"})
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/seaborn/categorical.py:381: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) < "3.0":
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /tmp/ipykernel_1284770/310630204.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticks(),fontdict={"size": "15"})
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/seaborn/categorical.py:381: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) < "3.0":
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /tmp/ipykernel_1284770/310630204.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticks(),fontdict={"size": "15"})
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/seaborn/categorical.py:381: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) < "3.0":
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /tmp/ipykernel_1284770/310630204.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticks(),fontdict={"size": "15"})
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/seaborn/categorical.py:381: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) < "3.0":
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /tmp/ipykernel_1284770/310630204.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticks(),fontdict={"size": "15"})
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/seaborn/categorical.py:381: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) < "3.0":
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /tmp/ipykernel_1284770/310630204.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticks(),fontdict={"size": "15"})
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/seaborn/categorical.py:381: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) < "3.0":
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /tmp/ipykernel_1284770/310630204.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticks(),fontdict={"size": "15"})
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/seaborn/categorical.py:381: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) < "3.0":
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /tmp/ipykernel_1284770/310630204.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticks(),fontdict={"size": "15"})
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/seaborn/categorical.py:381: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) < "3.0":
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /tmp/ipykernel_1284770/310630204.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticks(),fontdict={"size": "15"})
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/seaborn/categorical.py:381: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) < "3.0":
# /home/junsheng/BIN/anaconda3/envs/stat/lib/python3.10/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /tmp/ipykernel_1284770/310630204.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticks(),fontdict={"size": "15"})

# %% [markdown]
# # NGA50

# %%
df_nga50_Kbp=df_nga50/1000

# %%
fig,ax=plt.subplots(1,1,figsize=(12,8))
sns.heatmap(df_nga50_Kbp,cmap="coolwarm",annot=True)
ax.set_xticklabels(ax.get_xticklabels(), fontdict={"size": "15"})
ax.set_ylabel("NGA50 (Kbp)",fontdict={"size":"25"})
fig.savefig(
        "{}/{}.png".format(out_python,"heatmap_NGA50"),
        dpi=600,
        bbox_inches="tight",
        transparent=False,
    )
plt.close()

# %% [markdown]
# # genome fraction

# %%
fig,ax=plt.subplots(1,1,figsize=(12,8))
sns.heatmap(df_gf,cmap="coolwarm",annot=True)
ax.set_xticklabels(ax.get_xticklabels(), fontdict={"size": "15"})
ax.set_ylabel("Genome fraction (%)",fontdict={"size":"25"})
fig.savefig(
        "{}/{}.png".format(out_python,"heatmap_Genome_fraction"),
        dpi=600,
        bbox_inches="tight",
        transparent=False,
    )
plt.close()
